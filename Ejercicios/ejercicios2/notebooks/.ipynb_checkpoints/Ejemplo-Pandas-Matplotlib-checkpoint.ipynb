# %%
import pandas as pd
import sys
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from pandas.tools.plotting import radviz

# %matplotlib inline

# %%
df = pd.read_csv("data/defunciones.csv")

# %%
print df.shape
# Out:
# (63104, 53)

# %%
df.keys()
# Out:
# Index([u'Unnamed: 0', u'folio', u'ofi_insc', u'prov_insc', u'cant_insc',
#        u'parr_insc', u'anio_insc', u'mes_insc', u'dia_insc', u'fecha_insc',
#        u'acta_insc', u'sexo', u'anio_nac', u'mes_nac', u'dia_nac',
#        u'fecha_nac', u'anio_fall', u'mes_fall', u'dia_fall', u'fecha_fall',
#        u'nac_fall', u'cod_pais', u'edad', u'cod_edad', u'prov_res',
#        u'cant_res', u'parr_res', u'loc_res', u'area_res', u'est_civil',
#        u'sabe_leer', u'niv_inst', u'etnia', u'lugar_ocur', u'cod_esta',
#        u'prov_fall', u'cant_fall', u'parr_fall', u'loc_fall', u'area_fall',
#        u'causa4', u'mor_mat', u'mor_viol', u'lug_viol', u'autopsia',
#        u'cer_por', u'parent_fall', u'causa', u'causa103', u'causa80',
#        u'causa67A', u'causa67B', u'lc1'],
#       dtype='object')

# %%
print df.causa103.unique()
# Out:
# ['054 Resto de enferm.endocrinas, nutricionales y metab\xc3\xb3licas '
#  '046 Resto de tumores malignos                               '
#  '076 Enfermedades cr\xc3\xb3nicas de las v\xc3\xadas resp inferiores       '
#  '040 Tumor maligno de la pr\xc3\xb3stata                            '
#  '074 Neumonia                                                '
#  '093 Malformac cong\xc3\xa9nitas  deformidades y anomal cromosom    '
#  '047 Resto de tumores                                        '
#  '081 Resto de enfermedades del sistema digestivo             '
#  '052 Diabetes mellitus                                       '
#  '080 Enfermedades del h\xc3\xadgado                                 '
#  '103 Todas las dem\xc3\xa1s causas externas                         '
#  '069 Enfermedades Cerebro vasculares                          '
#  '070 Aterosclerosis                                          '
#  '092 Ciertas afecciones originadas en el periodo perinatal   '
#  '086 Resto de enfermedades del sistema genitourinario        '
#  '020 Enf por virus de la inmunodeficiencia humana (VIH)      '
#  '067 Enfermedades isqu\xc3\xa9micas del coraz\xc3\xb3n                     '
#  '057 Resto de trastornos mentales y del comportamiento      '
#  '049 Anemias                                                 '
#  '034 Tumor maligno de la tr\xc3\xa1quea de los bronquios y del pulm\xc3\xb3n  '
#  '096 Accidentes de transporte                                '
#  '036 Tumor maligno de la mama                                '
#  '079 Ulcera g\xc3\xa1strica y duodenal                              '
#  '068 Otras enfermedades del coraz\xc3\xb3n                          '
#  '043 Linfoma no Hodgkin                                      '
#  '005 Tuberculosis respiratoria                               '
#  '050 Resto de enfermedades de la sangre y organos hematopoy\xc3\xa9ticos y otros transtornos que afectan al mecanismo inmunol\xc3\xb3'
#  '029 Tumor maligno del estomago                              '
#  '025 Resto de ciertas enfermedades infecciosas y parasitarias            '
#  '066 Enfermedades hipertensivas                              '
#  '090 Muertes obst\xc3\xa9tricas indirectas                          '
#  '061 Resto de enfermedades del sistema nervioso              '
#  '097 Caidas                                                  '
#  '065 Fiebre reum\xc3\xa1tica aguda y enfermedades cardiacas reum\xc3\xa1ticas cr\xc3\xb3nicas '
#  '071 Resto de enfermedades del sistema circulatorio          '
#  '027 Tumor maligno del labio de la cavidad bucal y de la faringe '
#  '012 Septicemia                                              '
#  '031 Tumor maligno del h\xc3\xadgado y de las v\xc3\xadas biliares intrahepat '
#  '101 Lesiones autoinfligidas intencionalmente                '
#  '077 Resto de enfermedades del sistema respiratorio          '
#  '083 Enfermedades del sis osteomusc y del tejido conjuntivo  '
#  '039 Tumor maligno del ovario                                '
#  '035 Melanoma maligno de la piel                             '
#  '059 Meningitis                                              '
#  '028 Tumor maligno del es\xc3\xb3fago                               '
#  '098 Ahogamiento y sumersi\xc3\xb3n accidentales                    '
#  '013 Infecciones con un modo de transm.predom.sexual         '
#  '045 Leucemia                                                '
#  '056 Transtornos mentales y del comportamiento debido al uso de sustancias psicoactivas '
#  '003 Diarrea y gastroenteritis de presunto origen infeccioso'
#  '094 Sintomas, signos y hallazgos anormales  cl\xc3\xadnicos yde laboratorio  no clasificados en otra parte'
#  '038 Tumor maligno de las partes y de las no especificadas del \xc3\xbatero'
#  '030 Tumor maligno del colon  del recto y del ano            '
#  '060 Enfermedad de Alzheimer                                 '
#  '032 Tumor maligno del p\xc3\xa1ncreas                              '
#  '102 Agresiones                                              '
#  '088 Embarazo terminado en aborto                            '
#  '044 Mieloma multiple y tumores malignos de c\xc3\xa9lula plasm\xc3\xa1ticas'
#  '042 Tumor maligno de la mening, del encefalo y de otras partes del snc  '
#  '053 Desnutrici\xc3\xb3n                                            '
#  '075 Otras Infecciones agudas de las v\xc3\xadas respiratorias inferiores    '
#  '099 Exposici\xc3\xb3n al humo  fuego y llamas                      '
#  '089 Otras muertes obst\xc3\xa9tricas directas                       '
#  '100 Envenenamiento accidental por  y expos a sustan nocivas '
#  '037 Tumor maligno del cuello del \xc3\xbatero                      '
#  '033 Tumor maligno de la laringe                             '
#  '041 Tumor maligno de la vejiga urinaria                     '
#  '082 Enfermedades de la piel y del tejido subcut\xc3\xa1neo         '
#  '019 Hepatitis viral                                         '
#  '073 Influenza (Gripe)                                       '
#  '085 Enfermedades renales, glomerular y tubulointersticial   '
#  '022 Leishmaniasis                                           '
#  '021 Paludismo (Malaria)                                     '
#  '006 Otras tuberculosis                                      '
#  '017 Ot fieb virals transm. por artropod y fieb. hemorr. vir.'
#  '008 T\xc3\xa9tanos                                                 '
#  '011 Infecci\xc3\xb3n meningococica                                 '
#  '014 Poliomielitis aguda                                     '
#  '004 Otras enfermedades infecciosas intestinales             '
#  '023 Tripanosomiasis                                         '
#  '007 Peste                                                   '
#  '091 Resto de embarazo  parto y puerperio                    '
#  '009 Difteria                                                ']

# %%
df.causa103.value_counts()[:20].sort_values(inplace=False).plot('barh');
# https://stackoverflow.com/questions/44123874/dataframe-object-has-no-attribute-sort

# %%
df[df['prov_insc'].str.strip()=='Pichincha'].causa103.value_counts()[:15].sort_values(inplace=False).plot('barh');

# %%
df[df['prov_fall'].str.strip()=='Pichincha'].causa103.value_counts()[:15].sort_values(inplace=False).plot(kind='bar', title=u'Gráfico');

# %%
pichincha = df[df['prov_insc'].str.strip()=='Pichincha'].groupby('dia_fall').prov_insc.count()
guayas = df[df['prov_insc'].str.strip()=='Guayas'].groupby('dia_fall').prov_insc.count()
pichincha.plot(label='Pichincha')
guayas.plot(label='Guayas')
plt.legend(loc='best')
