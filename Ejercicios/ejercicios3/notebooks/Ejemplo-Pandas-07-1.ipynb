# %% [markdown]
# # Uso de Dataframe en Pandas
# ##### https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html

# %%
import pandas as pd
import sys
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from pandas.tools.plotting import radviz

# %matplotlib inline

## tomado de http://cursosinformatica.ucm.es/trial/analisis/

# %%
data = pd.read_csv('data/defunciones.csv')

# %%
data[data['prov_insc'].str.strip()=='Azuay']
# Out:
#        Unnamed: 0    folio  ofi_insc prov_insc  \
# 0               1      NaN         1    Azuay
# 1               2      NaN         1    Azuay
# 2               3      NaN         1    Azuay
# 3               4      NaN         1    Azuay
# 4               5      NaN         1    Azuay
# 5               6      NaN         1    Azuay
# 6               7      NaN         1    Azuay
# 7               8      NaN         1    Azuay
# 8               9      NaN         1    Azuay
# 9              10      NaN         1    Azuay
# 10             11      NaN         1    Azuay
# 11             12      NaN         1    Azuay
# 12             13      NaN         1    Azuay
# 13             14      NaN         1    Azuay
# 14             15      NaN         1    Azuay
# 15             16      NaN         1    Azuay
# 16             17      NaN         1    Azuay
# 17             18      NaN         1    Azuay
# 18             19      NaN         1    Azuay
# ...

# %%
print data.keys()
data.head()
# Out:
# Index([u'Unnamed: 0', u'folio', u'ofi_insc', u'prov_insc', u'cant_insc',
#        u'parr_insc', u'anio_insc', u'mes_insc', u'dia_insc', u'fecha_insc',
#        u'acta_insc', u'sexo', u'anio_nac', u'mes_nac', u'dia_nac',
#        u'fecha_nac', u'anio_fall', u'mes_fall', u'dia_fall', u'fecha_fall',
#        u'nac_fall', u'cod_pais', u'edad', u'cod_edad', u'prov_res',
#        u'cant_res', u'parr_res', u'loc_res', u'area_res', u'est_civil',
#        u'sabe_leer', u'niv_inst', u'etnia', u'lugar_ocur', u'cod_esta',
#        u'prov_fall', u'cant_fall', u'parr_fall', u'loc_fall', u'area_fall',
#        u'causa4', u'mor_mat', u'mor_viol', u'lug_viol', u'autopsia',
#        u'cer_por', u'parent_fall', u'causa', u'causa103', u'causa80',
#        u'causa67A', u'causa67B', u'lc1'],
#       dtype='object')
#    Unnamed: 0  folio  ofi_insc prov_insc  \
# 0           1    NaN         1    Azuay
# 1           2    NaN         1    Azuay
# 2           3    NaN         1    Azuay
# ...

# %%
data[data['prov_insc'].str.strip()=='Azuay'].pivot_table(index = 'mes_insc', columns = 'causa103', values = 'autopsia', aggfunc = sum)
# Out:
# causa103   003 Diarrea y gastroenteritis de presunto origen infeccioso  \
# mes_insc
# Abril                                           No  Ignorado
# Agosto                                                   None
# Diciembre                                                None
# Enero                                   No  Ignorado  No  Si
# Febrero                                                  None
# Julio                                                     No
# Junio                                                     No
# Marzo                                     Ignorado  Ignorado
# Mayo                                                      No
# Noviembre                                 Ignorado  Ignorado
# Octubre                                   Ignorado  Ignorado
# Septiembre                                               None
#
# causa103   005 Tuberculosis respiratoria                                 \
# mes_insc
# Abril                                                     Si
# ...
